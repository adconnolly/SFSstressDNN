# %%
import numpy as np
from scipy import stats

# %%
# Fine grid
r2=np.array([[0.9923, 0.9697, 0.9295, 0.9454, 0.9016, 0.8857], # bIn1
             [0.9926, 0.9707, 0.9285, 0.946,  0.9006, 0.8799], # bIn1
             [0.9828, 0.9409, 0.8613, 0.8932, 0.812 , 0.768 ], # bIn2
             [0.9843, 0.9413, 0.8617, 0.8899, 0.813 , 0.7607], # bIn2
             [0.9826, 0.9389, 0.8614, 0.8862, 0.8103, 0.7654], # bIn2
             [0.9824, 0.9389, 0.8626, 0.8884, 0.8122, 0.7592], # bIn3
             [0.9826, 0.9418, 0.8613, 0.8886, 0.8126, 0.7554], # bIn3
             [0.9824, 0.9367, 0.8613, 0.8903, 0.8142, 0.766 ], # bIn3
             [0.9836, 0.9402, 0.8636, 0.8833, 0.815 , 0.7676], # bIn4
             [0.9813, 0.9401, 0.8636, 0.8888, 0.8146, 0.7644]]) # bIn4
r2_noB=np.array([[0.9805, 0.9312, 0.8552, 0.8798, 0.801,  0.754 ], # bOut1
                 [0.9791, 0.9261, 0.8495, 0.875 , 0.793,  0.7356], # bOut1
                 [0.9804, 0.9294, 0.8543, 0.8759, 0.8002, 0.7542], # bOut1
                 [0.983 , 0.9301, 0.8531, 0.8725, 0.7984, 0.7501], # bOut2
                 [0.9793, 0.9292, 0.8535, 0.8758, 0.7997, 0.7459], # bOut2
                 [0.9802, 0.9285, 0.8525, 0.8764, 0.8012, 0.7526], # bOut2
                 [0.9796, 0.9291, 0.8458, 0.8797, 0.7913, 0.7401], # bOut3
                 [0.9811, 0.9304, 0.8563, 0.881 , 0.8039, 0.7589], # bOut3
                 [0.9801, 0.9277, 0.8557, 0.874 , 0.8022, 0.7554], # bOut4
                 [0.9825, 0.9271, 0.8547, 0.8764, 0.8028, 0.7567]])# bOut4

for ivar in range(r2.shape[1]):
    print(np.mean(r2[:,ivar]),np.std(r2[:,ivar]))
    print(np.mean(r2_noB[:,ivar]),np.std(r2_noB[:,ivar]))
    print(stats.ttest_ind(r2[:,ivar],r2_noB[:,ivar]))
# Out:
# 0.98469 0.0039510631480653355
# 0.98058 0.0012253978945632414
# Ttest_indResult(statistic=2.9806181797375206, pvalue=0.008016046325982192)
# 0.9459199999999999 0.01221972176442656
# 0.92888 0.0014844527611210818
# Ttest_indResult(statistic=4.152870725539744, pvalue=0.0005976475423857126)
# 0.8754799999999999 0.026774607373405118
# 0.8530599999999999 0.003035852433831383
# Ttest_indResult(statistic=2.4960877036449856, pvalue=0.022490130723974742)
# 0.90001 0.022975615334523684
# 0.8766499999999999 0.0025792440753057855
# Ttest_indResult(statistic=3.0311503744790693, pvalue=0.007181575474642779)
# 0.8306100000000001 0.03526994329453903
# 0.79937 0.003920982019851648
# Ttest_indResult(statistic=2.6409505150777073, pvalue=0.016603251489474304)
# 0.78723 0.047948243972016344
# 0.7503500000000001 0.007173736822605077
# Ttest_indResult(statistic=2.2820878220304834, pvalue=0.03486793078042832)

# %%
# Mid grid
r2=np.array([[0.9379, 0.7126, 0.7399, 0.7813, 0.6891, 0.6738], # bIn1
             [0.9369, 0.7154, 0.744,  0.7862, 0.6978, 0.6802], # bIn1
             [0.931,  0.6966, 0.742,  0.7871, 0.6953, 0.6686], # bIn1
             [0.935,  0.7088, 0.7434, 0.7879, 0.6962, 0.6815], # bIn1
             [0.9349, 0.7114, 0.7502, 0.7912, 0.6918, 0.6854], # bIn1
             [0.9308, 0.7048, 0.7496, 0.7875, 0.6961, 0.6741], # bIn2
             [0.9388, 0.713,  0.7486, 0.7891, 0.6968, 0.6832], # bIn2
             [0.9318, 0.7147, 0.7423, 0.7892, 0.6972, 0.6778], # bIn2
             [0.9328, 0.7145, 0.7516, 0.7856, 0.6998, 0.6796], # bIn2
             [0.9349, 0.7032, 0.737,  0.7857, 0.7001, 0.6793]])# bIn2
r2_noB=np.array([[0.9336, 0.6899, 0.7423, 0.7745, 0.6803, 0.6152], # bOut1
                 [0.9331, 0.6899, 0.7452, 0.773,  0.6852, 0.6714], # bOut1
                 [0.9277, 0.6801, 0.7426, 0.7742, 0.681,  0.6687], # bOut1
                 [0.9289, 0.6903, 0.7384, 0.7715, 0.6854, 0.6651], # bOut1
                 [0.9226, 0.6928, 0.731 , 0.7738, 0.6763, 0.6387], # bOut1
                 [0.9334, 0.6927, 0.7414, 0.7768, 0.6876, 0.6596], # bOut2
                 [0.9318, 0.6969, 0.733 , 0.7774, 0.6849, 0.6519], # bOut2
                 [0.9311, 0.7016, 0.7394, 0.774,  0.6856, 0.6701], # bOut2
                 [0.9316, 0.6994, 0.7474, 0.7809, 0.6821, 0.6685], # bOut2
                 [0.9302, 0.6943, 0.7277, 0.7745, 0.677,  0.6618]])# bOut2
for ivar in range(r2.shape[1]):
    print(np.mean(r2[:,ivar]),np.std(r2[:,ivar]))
    print(np.mean(r2_noB[:,ivar]),np.std(r2_noB[:,ivar]))
    print(stats.ttest_ind(r2[:,ivar],r2_noB[:,ivar]))
# Out:
# 0.9344800000000001 0.002692508124407417
# 0.9303999999999999 0.0031755314515841404
# Ttest_indResult(statistic=2.9399302891001398, pvalue=0.008755609391750768)
# 0.7095 0.005839520528262576
# 0.69279 0.0056958669226027355
# Ttest_indResult(statistic=6.1453531143406845, pvalue=8.379821821574731e-06)
# 0.7448599999999999 0.004630161984207482
# 0.7388399999999999 0.0060544529067455685
# Ttest_indResult(statistic=2.3694585484892783, pvalue=0.02919742698360326)
# 0.78708 0.002543147655957094
# 0.77506 0.002521983346495385
# Ttest_indResult(statistic=10.068070472084983, pvalue=8.044744013094682e-09)
# 0.6960200000000001 0.0031993124261315733
# 0.68254 0.003646971346199458
# Ttest_indResult(statistic=8.335752651306736, pvalue=1.3579568625298175e-07)
# 0.67835 0.0047240342928476
# 0.6571 0.016886562705299146
# Ttest_indResult(statistic=3.6356079932371843, pvalue=0.001891258568018449)

# %%
# Coarse grid
r2=np.array([[0.8415, 0.6617, 0.4879, 0.5999, 0.3678, 0.4072], # bIn1
             [0.8463, 0.6782, 0.5036, 0.6262, 0.3029, 0.4513], # bIn1
             [0.8435, 0.6673, 0.4644, 0.6044, 0.3504, 0.4019], # bIn1
             [0.8543, 0.669,  0.4771, 0.6104, 0.2921, 0.3557], # bIn1
             [0.8586, 0.661,  0.5235, 0.6188, 0.3041, 0.3288], # bIn1
             [0.834,  0.6656, 0.4787, 0.5661, 0.3942, 0.3798], # bIn2
             [0.8556, 0.6519, 0.4911, 0.5966, 0.3289, 0.4027], # bIn2
             [0.8305, 0.6634, 0.4949, 0.5138, 0.3857, 0.3573], # bIn2
             [0.8465, 0.66  , 0.5031, 0.621 , 0.3436, 0.389 ], # bIn2
             [0.846,  0.6561, 0.496 , 0.5723, 0.3232, 0.407 ]])# bIn2
r2_noB=np.array([[0.8279, 0.6417, 0.4656, 0.5694, 0.3827, 0.4392], # bOut1
                 [0.8234, 0.6715, 0.4758, 0.5974, 0.4077, 0.4212], # bOut1
                 [0.7793, 0.6352, 0.4656, 0.5606, 0.3526, 0.4115], # bOut1
                 [0.7985, 0.6605, 0.4796, 0.5509, 0.3723, 0.4559], # bOut1
                 [0.8106, 0.6605, 0.5106, 0.5519, 0.355,  0.4457], # bOut1
                 [0.7925, 0.6493, 0.4632, 0.5952, 0.3349, 0.4545], # bOut2
                 [0.8229, 0.6579, 0.4692, 0.5653, 0.2941, 0.425 ], # bOut2
                 [0.7954, 0.6759, 0.4702, 0.5499, 0.3562, 0.4494], # bOut2
                 [0.7811, 0.6525, 0.4454, 0.5578, 0.3717, 0.44  ], # bOut2
                 [0.7921, 0.6596, 0.4735, 0.5321, 0.293,  0.4707]])# bOut2

for ivar in range(r2.shape[1]):
    print(np.mean(r2[:,ivar]),np.std(r2[:,ivar]))
    print(np.mean(r2_noB[:,ivar]),np.std(r2_noB[:,ivar]))
    print(stats.ttest_ind(r2[:,ivar],r2_noB[:,ivar]))
    

# for ivar in range(r2.shape[1]):
#     print(np.mean(r2[:,ivar])-np.mean(r2_noB[:,ivar]))
# Out:
# 0.84568 0.00854327805938681
# 0.80237 0.016835501180541067
# Ttest_indResult(statistic=6.882201276156588, pvalue=1.9482982433461977e-06)
# 0.6634200000000001 0.0069006956171099145
# 0.65646 0.011770658435278787
# Ttest_indResult(statistic=1.530304931355709, pvalue=0.14332616760865888)
# 0.4920299999999999 0.015661101493828582
# 0.47187 0.015627670971709133
# Ttest_indResult(statistic=2.7336191448751244, pvalue=0.013640496546573037)
# 0.5929500000000001 0.03235720167134357
# 0.5630499999999999 0.01922307207498323
# Ttest_indResult(statistic=2.383317237972965, pvalue=0.02838117793395836)
# 0.33929 0.03358590329289953
# 0.35202000000000006 0.03463809463581968
# Ttest_indResult(statistic=-0.79154543205929, pvalue=0.43893265969000805)
# 0.38807 0.03271764202995075
# 0.44131 0.01703105692551112
# Ttest_indResult(statistic=-4.330219075644371, pvalue=0.00040317035796781685)
